# %%
from py3d import Vector3
import numpy
def st(log,sim):
    SST=((log-log.M.M).norm()**2).sum()
    SSR=((sim-log.M.M).norm()**2).sum()
    SSr=((log-sim.M.M).norm()**2).sum()
    SSE=((log-sim).norm()**2).sum()
    print(SST,SSR,SSr,SSE)
log=Vector3.Rand(10,30)
log.x=numpy.linspace(0,9,10)
sim=log[0:-3]+Vector3(x=0.2)
dt=sim[0][0][0]-log[0][0][0]
tmp=sim-Vector3(x=dt)
tmp_size=len(tmp)
i=0
while tmp[-1][0][0]<log[-1][0][0]:
    tmp+=Vector3(x=log[i][0][0]-tmp[0][0][0])
    st(log[i:i+tmp_size],tmp)
    i+=1
    print(i)
# Out:
# 872.0791210868366 872.0791210868366 872.0791210868366 0.0
# 1
# 873.623994116508 872.1256177496217 873.670490779293 73.12863282130601
# 2
# 873.8571671517971 872.1808804444956 873.958926509456 67.8921158722894
# 3
# 874.2038596186414 872.240253323406 874.3649918552106 69.96430277035675
# 4

# %%
from py3d import Space,Color
s=Space()
log.as_point(Color(r=1)).render(s)
sim.as_point(Color(g=1)).render(s)
# Out:
# click http://127.0.0.1:8002/view/9c27d184-6cb3-11ec-84b1-cd02d4b2a717 or http://172.22.247.233:8002/view/9c27d184-6cb3-11ec-84b1-cd02d4b2a717 to view in browser
#         <iframe
#             width="100%"
#             height="600px"
#             src="http://127.0.0.1:8002/view/9c27d184-6cb3-11ec-84b1-cd02d4b2a717"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import HTML,display
display(HTML(filename="/mnt/d/codes/scenario/py3d/doc/webpack 把html和js - 国内版 Bing.html"))
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0153)https://cn.bing.com/search?q=webpack+%E6%8A%8Ahtml%E5%92%8Cjs&cvid=0692ab0ae7624540bb2472c3741fe2b2&aqs=edge..69i57.62453j0j1&pglt=43&FORM=ANNTA1&PC=U531 -->
# <html dir="ltr" lang="zh" xml:lang="zh" xmlns="http://www.w3.org/1999/xhtml" xmlns:web="http://schemas.live.com/Web/"><script>
# (() => {
# /**
#  * This script injected by the installed three.js developer
#  * tools extension.
#  * https://github.com/threejs/three-devtools
#  */
#
# const $devtoolsReady = Symbol('devtoolsReady');
# const $backlog = Symbol('backlog');
#
# // The __THREE_DEVTOOLS__ target is small and light-weight, and collects
# // events triggered until the devtools panel is ready, which is when
# // the events are flushed.
# const target = new class ThreeDevToolsTarget extends EventTarget {
#   constructor() {
#     super();
#     this[$devtoolsReady] = false;
#     this[$backlog] = [];
#     this.addEventListener('devtools-ready', e => {
# ...

# %%
from py3d.server import test
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b1324603bdce> in <module>
# ----> 1 from py3d.server import test
#
# ImportError: cannot import name 'test' from 'py3d.server' (/home/tumiz/.local/lib/python3.8/site-packages/py3d/server.py)

# %%
from py3d.server import Space
s=Space()
# Out:
# click http://172.22.247.233:8003/view/e5026d48-6cb2-11ec-82dd-e94be77b7083 to view in browser
